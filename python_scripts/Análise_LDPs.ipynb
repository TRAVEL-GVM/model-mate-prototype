# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import obiwan as obi
import datetime

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Read data

# %%
df_final = pd.read_excel('dataframes.xlsx', sheet_name='df_final')
df_final_comh = pd.read_excel('dataframes.xlsx', sheet_name='df_final_comh').rename(columns={'Unnamed: 0': 'Date'})

quarterly_ecb_data = pd.read_excel('dataframes.xlsx', sheet_name='quarterly_ecb_data') 
annual_ecb_data = pd.read_excel('dataframes.xlsx', sheet_name='annual_ecb_data')
monthly_ecb_data = pd.read_excel('dataframes.xlsx', sheet_name='monthly_ecb_data')

# %%
display(
df_final.head(),
df_final_comh.head(),
quarterly_ecb_data.head(),
annual_ecb_data.head(),
monthly_ecb_data.head()
       )
# Out:
#         Date  Current ratio-C18 Printing  Current ratio-J58 Publishing  \
# 0 2006-12-31                      109.00                        130.65
# 1 2007-12-31                      112.31                        131.24
# 2 2008-12-31                      111.10                        124.05
# 3 2009-12-31                      112.33                        127.11
# 4 2010-12-31                      127.30                        122.00
#
#    Current ratio-H51 Air transport  Current ratio-G45 Trade motor vehicles  \
# 0                           171.56                                  114.21
# 1                           127.79                                  116.26
# 2                           125.44                                  110.88
# 3                           118.17                                  110.58
# 4                           151.35                                  115.62
#
#    Current ratio-F Construction  Current ratio-C20 Chemicals  \
# ...

# %% [markdown]
# # Analysis

# %%
#df_final.shape
#df_final_comh.shape
quarterly_ecb_data.shape
annual_ecb_data.shape
monthly_ecb_data.shape
# Out:
# (61, 2)

# %%
df_final_comh.head()
# Out:
#         Date  Liquidez geral_C18 Printing  Liquidez geral_J58 Publishing  \
# 0 2006-12-31                       109.00                         130.65
# 1 2007-12-31                       112.31                         131.24
# 2 2008-12-31                       111.10                         124.05
# 3 2009-12-31                       112.33                         127.11
# 4 2010-12-31                       127.30                         122.00
#
#    Liquidez geral_H51 Air transport  Liquidez geral_G45 Trade motor vehicles  \
# 0                            171.56                                   114.21
# 1                            127.79                                   116.26
# 2                            125.44                                   110.88
# 3                            118.17                                   110.58
# 4                            151.35                                   115.62
#
# ...

# %%
# END OF PERIOD
quarterly_ecb_data.head()
# Out:
#   TIME_PERIOD  Private final consumption, Portugal  \
# 0  2020-01-01                            -1.008016
# 1  2020-04-01                           -16.552394
# 2  2020-07-01                            -4.256041
# 3  2020-10-01                            -5.242758
# 4  2021-01-01                            -7.222002
#
#    Gross fixed capital formation, Portugal  \
# 0                                -1.259336
# 1                                -8.579667
# 2                                -0.101212
# 3                                 0.570004
# 4                                 3.803724
#
#    Gross entrepreneurial income of Non financial corporations as a ratio of gross value added, Portugal  \
# 0                                          41.658218
# 1                                          40.736724
# 2                                          40.767762
# 3                                          40.073375
# 4                                          40.641991
#
# ...

# %%
# END OF PERIOD
annual_ecb_data.head()
# Out:
#    TIME_PERIOD  Government final consumption, Portugal  \
# 0         2020                                0.398942
# 1         2021                                3.784391
# 2         2022                                1.656845
# 3         2023                                0.593048
# 4         2024                                1.053851
#
#    Imports of goods and services, Portugal  \
# 0                               -11.590377
# 1                                12.258844
# 2                                11.265565
# 3                                 1.796337
# 4                                 4.769482
#
#    Exports of goods and services, Portugal  \
# 0                               -18.334661
# 1                                12.034544
# 2                                17.152864
# 3                                 3.803727
# 4                                 3.418246
#
#    Gross domestic product at market prices, Portugal  \
# ...

# %%
df_final_comh.columns
# Out:
# Index(['Unnamed: 0', 'Liquidez geral', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9',
#        ...
#        'Unnamed: 215', 'Unnamed: 216', 'Unnamed: 217', 'Unnamed: 218',
#        'Unnamed: 219', 'Unnamed: 220', 'Unnamed: 221', 'Unnamed: 222',
#        'Unnamed: 223', 'Unnamed: 224'],
#       dtype='object', length=225)
